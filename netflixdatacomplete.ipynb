# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammedaslaan/DataScience/blob/main/netflixdatacomplete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df =pd.read_csv('/content/netflix_titles.csv')

# %%
df
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
df['listed_in'].unique()
# Out:
# array(['International TV Shows, TV Dramas, TV Sci-Fi & Fantasy',
#        'Dramas, International Movies',
#        'Horror Movies, International Movies',
#        'Action & Adventure, Independent Movies, Sci-Fi & Fantasy',
#        'Dramas', 'International TV Shows, TV Dramas, TV Mysteries',
#        'Horror Movies, International Movies, Thrillers',
#        'Dramas, Thrillers',
#        'Crime TV Shows, International TV Shows, TV Dramas',
#        'Crime TV Shows, Docuseries, International TV Shows',
#        'Documentaries, International Movies, Sports Movies',
#        'Independent Movies, Sci-Fi & Fantasy, Thrillers',
#        'Dramas, International Movies, Thrillers',
#        'International TV Shows, TV Dramas',
#        'Comedies, Dramas, Independent Movies', 'Sports Movies',
#        'Dramas, Independent Movies, International Movies',
#        'Action & Adventure, Dramas, International Movies',
#        'Anime Series, International TV Shows', 'Documentaries',
# ...

# %%
sum(df['listed_in'].str.contains('Kids'))
# Out:
# 414

# %%
df[df['listed_in'].str.contains('Kids')]
# Out:
#      show_id     type                           title     director  \
# 108     s109  TV Show        3Below: Tales of Arcadia          NaN
# 111     s112  TV Show                         44 Cats          NaN
# 225     s226  TV Show  A Series of Unfortunate Events          NaN
# 276     s277  TV Show                    Abby Hatcher  Kyran Kelly
# 364     s365  TV Show                    Akbar Birbal          NaN
# ...      ...      ...                             ...          ...
# 7756   s7757  TV Show                              Z4          NaN
# 7759   s7760  TV Show                       Zak Storm          NaN
# 7766   s7767  TV Show                    Zig & Sharko          NaN
# 7775   s7776  TV Show                      Zoids Wild          NaN
# 7777   s7778  TV Show                     Zombie Dumb          NaN
#
#                                                    cast  \
# 108   Tatiana Maslany, Diego Luna, Nick Offerman, Ni...
# ...

# %%
sum(df['listed_in'].str.contains('Child'))
# Out:
# 532

# %%
child = sum(df['listed_in'].str.contains('Kids'))

# %%
sns.countplot(x = df['listed_in'].str.contains('Child'))
# Out:
# <AxesSubplot:xlabel='listed_in', ylabel='count'>

# %%
##**Make a visualization showing the total number of standup comedies**
# Out:
#   File "<ipython-input-20-bbedfe3fc077>", line 1
#     **Make a visualization showing the total number of standup comedies**
#     ^
# SyntaxError: invalid syntax

# %%
sum(df['listed_in'].str.contains('Stand'))
# Out:
# 381

# %%
set(df['listed_in'])
# Out:
# {'Action & Adventure',
#  'Action & Adventure, Anime Features, Children & Family Movies',
#  'Action & Adventure, Anime Features, Classic Movies',
#  'Action & Adventure, Anime Features, Horror Movies',
#  'Action & Adventure, Anime Features, International Movies',
#  'Action & Adventure, Anime Features, Sci-Fi & Fantasy',
#  'Action & Adventure, Children & Family Movies',
#  'Action & Adventure, Children & Family Movies, Classic Movies',
#  'Action & Adventure, Children & Family Movies, Comedies',
#  'Action & Adventure, Children & Family Movies, Dramas',
#  'Action & Adventure, Children & Family Movies, Independent Movies',
#  'Action & Adventure, Children & Family Movies, Sci-Fi & Fantasy',
#  'Action & Adventure, Classic Movies',
#  'Action & Adventure, Classic Movies, Comedies',
#  'Action & Adventure, Classic Movies, Cult Movies',
#  'Action & Adventure, Classic Movies, Dramas',
#  'Action & Adventure, Classic Movies, International Movies',
# ...

# %%
sum(df['listed_in'].str.contains('Stand-Up Comedy'))
# Out:
# 381

# %%
suc = df[df['listed_in'].str.contains('Stand-Up Comedy')]

# %%
suc
# Out:
#      show_id     type                                        title  \
# 197     s198  TV Show             A Little Help with Carol Burnett
# 220     s221    Movie                   A Russell Peters Christmas
# 284     s285  TV Show                              Abnormal Summit
# 305     s306    Movie          Adam Devine: Best Time of Our Lives
# 307     s308    Movie                      ADAM SANDLER 100% FRESH
# ...      ...      ...                                          ...
# 7718   s7719    Movie               Yoo Byung Jae: Discomfort Zone
# 7719   s7720    Movie          Yoo Byung Jae: Too Much Information
# 7744   s7745    Movie                  Yours Sincerely, Kanan Gill
# 7757   s7758    Movie  Zach Galifianakis: Live at the Purple Onion
# 7779   s7780  TV Show                                    Zona Rosa
#
#                      director  \
# 197                       NaN
# 220        Henry Sarwer-Foner
# 284   Jung-ah Im, Seung-uk Jo
# 305                 Jay Karas
# ...

# %%
plt.bar(['Child Shows','Stand-Up Comedy'],[child,len(suc)])
# Out:
# <BarContainer object of 2 artists>

# %%
plt.pie([child,len(suc)],labels=['Child Shows','Stand-Up Comedy'],autopct='%2.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9fff24b370>,
# ...
#  [Text(-0.07167226702498677, 1.097662555678884, 'Child Shows'),
#   Text(0.07167216425440096, -1.0976625623893213, 'Stand-Up Comedy')],
#  [Text(-0.03909396383181096, 0.5987250303703003, '52.08%'),
#   Text(0.039093907775127786, -0.5987250340305388, '47.92%')])

# %%
##Make a visualization showing most watched shows.

# %%
df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
shows = df['type'].str.contains('TV Show')

# %%
df[shows]
# Out:
#      show_id     type                  title              director  \
# 0         s1  TV Show                     3%                   NaN
# 5         s6  TV Show                     46           Serdar Akar
# 11       s12  TV Show                   1983                   NaN
# 12       s13  TV Show                   1994  Diego Enrique Osorno
# 16       s17  TV Show                 Feb-09                   NaN
# ...      ...      ...                    ...                   ...
# 7767   s7768  TV Show     Zindagi Gulzar Hai                   NaN
# 7775   s7776  TV Show             Zoids Wild                   NaN
# 7777   s7778  TV Show            Zombie Dumb                   NaN
# 7779   s7780  TV Show              Zona Rosa                   NaN
# 7785   s7786  TV Show  Zumbo's Just Desserts                   NaN
#
#                                                    cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
seasons = df[df.duration.str.contains('Season')]

# %%
seasons
# Out:
#      show_id     type                  title              director  \
# 0         s1  TV Show                     3%                   NaN
# 5         s6  TV Show                     46           Serdar Akar
# 11       s12  TV Show                   1983                   NaN
# 12       s13  TV Show                   1994  Diego Enrique Osorno
# 16       s17  TV Show                 Feb-09                   NaN
# ...      ...      ...                    ...                   ...
# 7767   s7768  TV Show     Zindagi Gulzar Hai                   NaN
# 7775   s7776  TV Show             Zoids Wild                   NaN
# 7777   s7778  TV Show            Zombie Dumb                   NaN
# 7779   s7780  TV Show              Zona Rosa                   NaN
# 7785   s7786  TV Show  Zumbo's Just Desserts                   NaN
#
#                                                    cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
seasons.sort_values(by='duration',ascending=False)
# Out:
#      show_id     type                         title            director  \
# 4404   s4405  TV Show                        Naruto         Hayato Date
# 2237   s2238  TV Show                Forensic Files                 NaN
# 468     s469  TV Show         American Horror Story                 NaN
# 5818   s5819  TV Show                    Still Game                 NaN
# 1181   s1182  TV Show              Call the Midwife  Philippa Lowthorpe
# ...      ...      ...                           ...                 ...
# 4225   s4226  TV Show                   More to Say                 NaN
# 4220   s4221  TV Show       Monzón: A Knockout Blow                 NaN
# 4219   s4220  TV Show  Monty Python's Personal Best                 NaN
# 1519   s1520  TV Show                      Crashing                 NaN
# 7785   s7786  TV Show         Zumbo's Just Desserts                 NaN
#
#                                                    cast  \
# ...

# %%
incresingseasons = seasons.sort_values(by='duration',ascending=False)

# %%
incresingseasons['duration'].astype(str).str[0]
# Out:
# 4404    9
# 2237    9
# 468     9
# 5818    9
# 1181    9
#        ..
# 4225    1
# 4220    1
# 4219    1
# 1519    1
# 7785    1
# Name: duration, Length: 2410, dtype: object

# %%
set(seasons.duration)
# Out:
# {'1 Season',
#  '10 Seasons',
#  '11 Seasons',
#  '12 Seasons',
#  '13 Seasons',
#  '15 Seasons',
#  '16 Seasons',
#  '2 Seasons',
#  '3 Seasons',
#  '4 Seasons',
#  '5 Seasons',
#  '6 Seasons',
#  '7 Seasons',
#  '8 Seasons',
#  '9 Seasons'}

# %%
seasons = seasons[seasons.duration.str.startswith('1')]

# %%
seasons
# Out:
#      show_id     type                  title              director  \
# 5         s6  TV Show                     46           Serdar Akar
# 11       s12  TV Show                   1983                   NaN
# 12       s13  TV Show                   1994  Diego Enrique Osorno
# 16       s17  TV Show                 Feb-09                   NaN
# 26       s27  TV Show               (Un)Well                   NaN
# ...      ...      ...                    ...                   ...
# 7766   s7767  TV Show           Zig & Sharko                   NaN
# 7767   s7768  TV Show     Zindagi Gulzar Hai                   NaN
# 7775   s7776  TV Show             Zoids Wild                   NaN
# 7779   s7780  TV Show              Zona Rosa                   NaN
# 7785   s7786  TV Show  Zumbo's Just Desserts                   NaN
#
#                                                    cast  \
# 5     Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# ...

# %%
sns.countplot(x=seasons.duration)
# Out:
# <AxesSubplot:xlabel='duration', ylabel='count'>

# %%
len(seasons[seasons.duration.str.startswith('1')])
# Out:
# 1624

# %%
len(seasons[seasons.duration.str.startswith('1 ')])
# Out:
# 1608

# %%
ten = seasons[seasons.duration.str.startswith('10')]

# %%
eleven = seasons[seasons.duration.str.startswith('11')]

# %%
twelve = seasons[seasons.duration.str.startswith('12')]
thirteen = seasons[seasons.duration.str.startswith('13')]
fifteen = seasons[seasons.duration.str.startswith('15')]
sixteen = seasons[seasons.duration.str.startswith('16')]

# %%
plt.bar([10,11,12,13,15,16],[len(ten),len(eleven),len(twelve),len(thirteen),len(fifteen),len(sixteen)])
# Out:
# <BarContainer object of 6 artists>

# %%
###Make a visualization showing highest rated show Make a dashboard (DASHBOARD A) containing all of these above visualizations

# %%
df.rating
# Out:
# 0       TV-MA
# 1       TV-MA
# 2           R
# 3       PG-13
# 4       PG-13
#         ...
# 7782    TV-MA
# 7783    TV-14
# 7784    TV-MA
# 7785    TV-PG
# 7786    TV-MA
# Name: rating, Length: 7787, dtype: object

# %%
sns.countplot(y = df.rating)
# Out:
# <AxesSubplot:xlabel='count', ylabel='rating'>

# %%
plt.figure(figsize=(16,9))
plt.subplot(2,2,1)
sns.countplot(y = df.rating)
plt.subplot(2,2,2)
plt.bar([10,11,12,13,15,16],[len(ten),len(eleven),len(twelve),len(thirteen),len(fifteen),len(sixteen)])
plt.subplot(2,2,3)
plt.pie([child,len(suc)],labels=['Child Shows','Stand-Up Comedy'],autopct='%2.2f%%')
plt.subplot(2,2,4)
plt.bar(['Child Shows','Stand-Up Comedy'],[child,len(suc)])
# Out:
# <BarContainer object of 2 artists>
